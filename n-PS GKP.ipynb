# %%
# The usual imports
import strawberryfields as sf
import numpy as np
import matplotlib.pyplot as plt
import matplotlib as mpl
from matplotlib import cm

# %% [markdown]
# The fock backend is substantially slow with cutoff_dim = 50

# %%
# Finite energy GKP pure state using "bosonic" backend
epsilon = 0.1
nmodes = 1
prog_gkp = sf.Program(nmodes)

with prog_gkp.context as q:
    sf.ops.GKP(epsilon=epsilon) | q[0]
    
      
eng = sf.Engine("bosonic")
gkp = eng.run(prog_gkp).state

Wgkp = gkp.wigner(mode=0, xvec=quad_axis, pvec=quad_axis)
scale = np.max(Wgkp.real)
nrm = mpl.colors.Normalize(-scale, scale)
plt.axes().set_aspect("equal")
plt.contourf(quad_axis, quad_axis, Wgkp, 60, cmap=cm.RdBu, norm=nrm)
plt.xlabel(r"q (units of $\sqrt{\hbar}$)", fontsize=15)
plt.ylabel(r"p (units of $\sqrt{\hbar}$)", fontsize=15)
plt.tight_layout()
plt.show()

# %%
# Finite energy GKP pure state using "fock" backend
epsilon = 0.1
nmodes = 1
prog_gkp = sf.Program(nmodes)

with prog_gkp.context as q:
    sf.ops.GKP(epsilon=epsilon) | q
    
      
eng = sf.Engine("fock", backend_options={"cutoff_dim":50})
gkp = eng.run(prog_gkp).state

Wgkp = gkp.wigner(mode=0, xvec=quad_axis, pvec=quad_axis)
scale = np.max(Wgkp.real)
nrm = mpl.colors.Normalize(-scale, scale)
plt.axes().set_aspect("equal")
plt.contourf(quad_axis, quad_axis, Wgkp, 60, cmap=cm.RdBu, norm=nrm)
plt.xlabel(r"q (units of $\sqrt{\hbar}$)", fontsize=15)
plt.ylabel(r"p (units of $\sqrt{\hbar}$)", fontsize=15)
plt.tight_layout()
plt.show()

# %% [markdown]
# Guesswork -- There *might* be large disparity between even and odd photon subtractions.

# %%
# 0 photon subtraction / 0 photon catalysis
# Create GKP state
epsilon = 0.1
nmodes =2
prog_gkp = sf.Program(nmodes)

with prog_gkp.context as q:
    sf.ops.GKP(epsilon=epsilon) | q[0]
    sf.ops.Vacuum() | q[1]
    sf.ops.BSgate(np.arccos(np.sqrt(0.75)),0) | (q[0],q[1])
    sf.ops.MeasureFock(select = 0) | q[1]
      
eng = sf.Engine("fock", backend_options={"cutoff_dim": 50})
gkp = eng.run(prog_gkp).state

Wgkp = gkp.wigner(mode=0, xvec=quad_axis, pvec=quad_axis)
scale = np.max(Wgkp.real)
nrm = mpl.colors.Normalize(-scale, scale)
plt.axes().set_aspect("equal")
plt.contourf(quad_axis, quad_axis, Wgkp, 60, cmap=cm.RdBu, norm=nrm)
plt.xlabel(r"q (units of $\sqrt{\hbar}$)", fontsize=15)
plt.ylabel(r"p (units of $\sqrt{\hbar}$)", fontsize=15)
plt.tight_layout()
plt.show()

# %%
# 1 photon subtraction
epsilon = 0.1
nmodes =2
prog_gkp = sf.Program(nmodes)

with prog_gkp.context as q:
    sf.ops.GKP(epsilon=epsilon) | q[0]
    sf.ops.Vacuum() | q[1]
    sf.ops.BSgate(np.arccos(np.sqrt(0.75)),0) | (q[0],q[1])
    sf.ops.MeasureFock(select = 1) | q[1]
      
eng = sf.Engine("fock", backend_options={"cutoff_dim": 50})
gkp = eng.run(prog_gkp).state

Wgkp = gkp.wigner(mode=0, xvec=quad_axis, pvec=quad_axis)
scale = np.max(Wgkp.real)
nrm = mpl.colors.Normalize(-scale, scale)
plt.axes().set_aspect("equal")
plt.contourf(quad_axis, quad_axis, Wgkp, 60, cmap=cm.RdBu, norm=nrm)
plt.xlabel(r"q (units of $\sqrt{\hbar}$)", fontsize=15)
plt.ylabel(r"p (units of $\sqrt{\hbar}$)", fontsize=15)
plt.tight_layout()
plt.show()

# %%
# 2 photon subtraction
# Create GKP state
epsilon = 0.1
nmodes =2
prog_gkp = sf.Program(nmodes)

with prog_gkp.context as q:
    sf.ops.GKP(epsilon=epsilon) | q[0]
    sf.ops.Vacuum() | q[1]
    sf.ops.BSgate(np.arccos(np.sqrt(0.75)),0) | (q[0],q[1])
    sf.ops.MeasureFock(select = 2) | q[1]
      
eng = sf.Engine("fock", backend_options={"cutoff_dim": 50})
gkp = eng.run(prog_gkp).state

Wgkp = gkp.wigner(mode=0, xvec=quad_axis, pvec=quad_axis)
scale = np.max(Wgkp.real)
nrm = mpl.colors.Normalize(-scale, scale)
plt.axes().set_aspect("equal")
plt.contourf(quad_axis, quad_axis, Wgkp, 60, cmap=cm.RdBu, norm=nrm)
plt.xlabel(r"q (units of $\sqrt{\hbar}$)", fontsize=15)
plt.ylabel(r"p (units of $\sqrt{\hbar}$)", fontsize=15)
plt.tight_layout()
plt.show()

# %%
# 3 photon subtraction 
# Create GKP state
epsilon = 0.1
nmodes =2
prog_gkp = sf.Program(nmodes)

with prog_gkp.context as q:
    sf.ops.GKP(epsilon=epsilon) | q[0]
    sf.ops.Vacuum() | q[1]
    sf.ops.BSgate(np.arccos(np.sqrt(0.75)),0) | (q[0],q[1])
    sf.ops.MeasureFock(select = 3) | q[1]
      
eng = sf.Engine("fock", backend_options={"cutoff_dim": 50})
gkp = eng.run(prog_gkp).state

Wgkp = gkp.wigner(mode=0, xvec=quad_axis, pvec=quad_axis)
scale = np.max(Wgkp.real)
nrm = mpl.colors.Normalize(-scale, scale)
plt.axes().set_aspect("equal")
plt.contourf(quad_axis, quad_axis, Wgkp, 60, cmap=cm.RdBu, norm=nrm)
plt.xlabel(r"q (units of $\sqrt{\hbar}$)", fontsize=15)
plt.ylabel(r"p (units of $\sqrt{\hbar}$)", fontsize=15)
plt.tight_layout()
plt.show()

# %%
# 4 photon subtraction 
# Create GKP state
epsilon = 0.1
nmodes =2
prog_gkp = sf.Program(nmodes)

with prog_gkp.context as q:
    sf.ops.GKP(epsilon=epsilon) | q[0]
    sf.ops.Vacuum() | q[1]
    sf.ops.BSgate(np.arccos(np.sqrt(0.75)),0) | (q[0],q[1])
    sf.ops.MeasureFock(select = 4) | q[1]
      
eng = sf.Engine("fock", backend_options={"cutoff_dim": 50})
gkp = eng.run(prog_gkp).state

Wgkp = gkp.wigner(mode=0, xvec=quad_axis, pvec=quad_axis)
scale = np.max(Wgkp.real)
nrm = mpl.colors.Normalize(-scale, scale)
plt.axes().set_aspect("equal")
plt.contourf(quad_axis, quad_axis, Wgkp, 60, cmap=cm.RdBu, norm=nrm)
plt.xlabel(r"q (units of $\sqrt{\hbar}$)", fontsize=15)
plt.ylabel(r"p (units of $\sqrt{\hbar}$)", fontsize=15)
plt.tight_layout()
plt.show()

# %%
# 5 photon subtraction 
# Create GKP state
epsilon = 0.1
nmodes =2
prog_gkp = sf.Program(nmodes)

with prog_gkp.context as q:
    sf.ops.GKP(epsilon=epsilon) | q[0]
    sf.ops.Vacuum() | q[1]
    sf.ops.BSgate(np.arccos(np.sqrt(0.75)),0) | (q[0],q[1])
    sf.ops.MeasureFock(select = 5) | q[1]
      
eng = sf.Engine("fock", backend_options={"cutoff_dim": 50})
gkp = eng.run(prog_gkp).state

Wgkp = gkp.wigner(mode=0, xvec=quad_axis, pvec=quad_axis)
scale = np.max(Wgkp.real)
nrm = mpl.colors.Normalize(-scale, scale)
plt.axes().set_aspect("equal")
plt.contourf(quad_axis, quad_axis, Wgkp, 60, cmap=cm.RdBu, norm=nrm)
plt.xlabel(r"q (units of $\sqrt{\hbar}$)", fontsize=15)
plt.ylabel(r"p (units of $\sqrt{\hbar}$)", fontsize=15)
plt.tight_layout()
plt.show()

# %%
# 6 photon subtraction 
# Create GKP state
epsilon = 0.1
nmodes =2
prog_gkp = sf.Program(nmodes)

with prog_gkp.context as q:
    sf.ops.GKP(epsilon=epsilon) | q[0]
    sf.ops.Vacuum() | q[1]
    sf.ops.BSgate(np.arccos(np.sqrt(0.75)),0) | (q[0],q[1])
    sf.ops.MeasureFock(select = 6) | q[1]
      
eng = sf.Engine("fock", backend_options={"cutoff_dim": 50})
gkp = eng.run(prog_gkp).state

Wgkp = gkp.wigner(mode=0, xvec=quad_axis, pvec=quad_axis)
scale = np.max(Wgkp.real)
nrm = mpl.colors.Normalize(-scale, scale)
plt.axes().set_aspect("equal")
plt.contourf(quad_axis, quad_axis, Wgkp, 60, cmap=cm.RdBu, norm=nrm)
plt.xlabel(r"q (units of $\sqrt{\hbar}$)", fontsize=15)
plt.ylabel(r"p (units of $\sqrt{\hbar}$)", fontsize=15)
plt.tight_layout()
plt.show()
